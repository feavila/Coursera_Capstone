# %% [markdown]
# # Applied Data Science Capstone Project: The Battle of Neighborhoods
# **This assignment was made by Felipe Avila Gritti, as part of the IBM Data Science Professional Certificate Program**

# %% [markdown]
# ### 1.1) Business Problem
# Ahead of the Tokyo 2020 - or 2021, due to COVID-19 Pandemic, Summer Olympic and Paralympics Games, in a the possibility of crowd presence, how could we provide support to different visitors to list and visualize Tokyo districts that fit their needs in term of culinary/ food venues?
#
# ### 1.2) Background overview
# With nearly 44 million inhabitants and the highest metropolitan GDP in the world, an estimated 600,000 overseas visitors are expected to flock to the Japanese capital and surrounding regions to attend this upcoming event.
#
# Tokyo is well-known as the restaurant capital of the world, with over 160,000 places to choose from around it’s 23 districts.
# I believe it’s difficult for a travelers, especially restaurant-goers, to make a choice from among many options since there is also too much information on the web because everybody’s got their own take of where to go and it’s all so fragmented that you have to assemble it yourself especially if you’re wanting non-touristy recommendations.
#
# So, how could we leverage Foursquare location data and machine learning to help us make decision and find appropriate neighborhoods? This is the problem I would like to address in this capstone project taking Tokyo as an example. In this project, I am going to use Foursquare location data and clustering methods to group the districts to different group by their restaurant venues information.
#
# ### 2) Using Data to Problem-Solving
# **Tokyo data that contains list districts (Wards) along with their latitude and longitude:**
# <br/>Datasource : https://en.wikipedia.org/wiki/Special_wards_of_Tokyo#List_of_special_wards
# <br/>Description: We will Scrap Tokyo districts (Wards) Table from Wikipedia and get the coordinates of these 23 major districts using geocoder class of Geopy client.
# <br/>
# **Restaurants in each neighborhood of Tokyo:**
# <br/>Data source: Foursquare APIs
# <br/>Description : By using this API we will get all the venues in each neighborhood. We can filter these venues to get only restaurants.

# %% [markdown]
# ### 3.1) Importing Packages

# %%
import numpy as np 
import pandas as pd 

# !conda install -c conda-forge lxml --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.11.8  |       ha878542_0         145 KB  conda-forge
#     certifi-2020.11.8          |   py36h5fab9bb_0         150 KB  conda-forge
#     libxml2-2.9.10             |       hb55368b_3         1.2 MB
#     libxslt-1.1.34             |       hc22bd24_0         432 KB
#     lxml-4.6.1                 |   py36h17c4326_0         1.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   libxslt            pkgs/main/linux-64::libxslt-1.1.34-hc22bd24_0
#   lxml               conda-forge/linux-64::lxml-4.6.1-py36h17c4326_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.6.20-hecda079_0 --> 2020.11.8-ha878542_0
#   certifi                          2020.6.20-py36h9880bd3_2 --> 2020.11.8-py36h5fab9bb_0
#   libxml2             conda-forge::libxml2-2.9.9-h13577e0_2 --> pkgs/main::libxml2-2.9.10-hb55368b_3
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# libxml2-2.9.10       | 1.2 MB    | ##################################### | 100%
# lxml-4.6.1           | 1.4 MB    | ##################################### | 100%
# libxslt-1.1.34       | 432 KB    | ##################################### | 100%
# certifi-2020.11.8    | 150 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ### 3.2) Using Pandas to transform the data in the table on the Wikipedia page into a dataframe

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Special_wards_of_Tokyo#List_of_special_wards')[3]

# %%
df.head()
# Out:
#   No. Flag      Name Kanji  Population(as of October 2016  Density(/km2)  \
# 0  01  NaN   Chiyoda  千代田区                          59441           5100
# 1  02  NaN      Chūō   中央区                         147620          14460
# 2  03  NaN    Minato    港区                         248071          12180
# 3  04  NaN  Shinjuku   新宿区                         339211          18620
# 4  05  NaN    Bunkyō   文京区                         223389          19790
#
#    Area(km2)                                    Major districts
# 0      11.66  Nagatachō, Kasumigaseki, Ōtemachi, Marunouchi,...
# 1      10.21  Nihonbashi, Kayabachō, Ginza, Tsukiji, Hatchōb...
# 2      20.37  Odaiba, Shinbashi, Hamamatsuchō, Mita, Roppong...
# 3      18.22  Shinjuku, Takadanobaba, Ōkubo, Kagurazaka, Ich...
# 4      11.29                              Hongō, Yayoi, Hakusan

# %% [markdown]
# ### 3.3) Only process the cells that have an assigned borough

# %%
df.drop("Flag", axis=1, inplace=True)

# %%
df.drop("Major districts", axis=1, inplace=True)

# %%
df.rename(columns={df.columns[3]:"Population"}, inplace=True)

# %%
df = df.rename(columns={"Density(/km2)": "Density"})

# %%
df = df.rename(columns={"Area(km2)": "Area"})

# %%
df
# Out:
#         No.        Name    Kanji  Population  Density    Area
# 0        01     Chiyoda     千代田区       59441     5100   11.66
# 1        02        Chūō      中央区      147620    14460   10.21
# 2        03      Minato       港区      248071    12180   20.37
# 3        04    Shinjuku      新宿区      339211    18620   18.22
# 4        05      Bunkyō      文京区      223389    19790   11.29
# 5        06       Taitō      台東区      200486    19830   10.11
# 6        07      Sumida      墨田区      260358    18910   13.77
# 7        08        Kōtō      江東区      502579    12510   40.16
# 8        09   Shinagawa      品川区      392492    17180   22.84
# 9        10      Meguro      目黒区      280283    19110   14.67
# 10       11         Ōta      大田区      722608    11910   60.66
# 11       12    Setagaya     世田谷区      910868    15690   58.05
# 12       13     Shibuya      渋谷区      227850    15080   15.11
# 13       14      Nakano      中野区      332902    21350   15.59
# 14       15    Suginami      杉並区      570483    16750   34.06
# 15       16     Toshima      豊島区      294673    22650   13.01
# 16       17        Kita       北区      345063    16740   20.61
# 17       18     Arakawa      荒川区      213648    21030   10.16
# 18       19    Itabashi      板橋区      569225    17670   32.22
# 19       20      Nerima      練馬区      726748    15120   48.08
# 20       21      Adachi      足立区      674067    12660   53.25
# 21       22  Katsushika      葛飾区      447140    12850   34.80
# 22       23     Edogawa     江戸川区      685899    13750   49.90
# 23  Overall     Overall  Overall     9375104    15146  619.00

# %%
df.drop([23], inplace=True)

# %%
df
# Out:
#    No.        Name Kanji  Population  Density   Area
# 0   01     Chiyoda  千代田区       59441     5100  11.66
# 1   02        Chūō   中央区      147620    14460  10.21
# 2   03      Minato    港区      248071    12180  20.37
# 3   04    Shinjuku   新宿区      339211    18620  18.22
# 4   05      Bunkyō   文京区      223389    19790  11.29
# 5   06       Taitō   台東区      200486    19830  10.11
# 6   07      Sumida   墨田区      260358    18910  13.77
# 7   08        Kōtō   江東区      502579    12510  40.16
# 8   09   Shinagawa   品川区      392492    17180  22.84
# 9   10      Meguro   目黒区      280283    19110  14.67
# 10  11         Ōta   大田区      722608    11910  60.66
# 11  12    Setagaya  世田谷区      910868    15690  58.05
# 12  13     Shibuya   渋谷区      227850    15080  15.11
# 13  14      Nakano   中野区      332902    21350  15.59
# 14  15    Suginami   杉並区      570483    16750  34.06
# 15  16     Toshima   豊島区      294673    22650  13.01
# 16  17        Kita    北区      345063    16740  20.61
# 17  18     Arakawa   荒川区      213648    21030  10.16
# 18  19    Itabashi   板橋区      569225    17670  32.22
# 19  20      Nerima   練馬区      726748    15120  48.08
# 20  21      Adachi   足立区      674067    12660  53.25
# 21  22  Katsushika   葛飾区      447140    12850  34.80
# 22  23     Edogawa  江戸川区      685899    13750  49.90

# %% [markdown]
# ### 3.4) Usage of .shape method to print the number of rows of the dataframe.

# %%
df.shape
# Out:
# (23, 6)

# %% [markdown]
# ### 4) Adding Geospatial Data

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
geolocator = Nominatim(user_agent="Tokyo_explorer")

df['Major_Dist_Coord']= df['Kanji'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = df['Major_Dist_Coord'].apply(pd.Series)

df.drop(['Major_Dist_Coord'], axis=1, inplace=True)
df
# Out:
#    No.        Name Kanji  Population  Density   Area   Latitude   Longitude
# 0   01     Chiyoda  千代田区       59441     5100  11.66  35.693810  139.753216
# 1   02        Chūō   中央区      147620    14460  10.21  35.666255  139.775565
# 2   03      Minato    港区      248071    12180  20.37  35.643227  139.740055
# 3   04    Shinjuku   新宿区      339211    18620  18.22  35.693763  139.703632
# 4   05      Bunkyō   文京区      223389    19790  11.29  35.718810  139.744732
# 5   06       Taitō   台東区      200486    19830  10.11  35.717450  139.790859
# 6   07      Sumida   墨田区      260358    18910  13.77  35.700429  139.805017
# 7   08        Kōtō   江東区      502579    12510  40.16  35.649154  139.812790
# 8   09   Shinagawa   品川区      392492    17180  22.84  35.599252  139.738910
# 9   10      Meguro   目黒区      280283    19110  14.67  35.621250  139.688014
# 10  11         Ōta   大田区      722608    11910  60.66  35.561206  139.715843
# 11  12    Setagaya  世田谷区      910868    15690  58.05  35.646096  139.656270
# 12  13     Shibuya   渋谷区      227850    15080  15.11  35.664596  139.698711
# 13  14      Nakano   中野区      332902    21350  15.59  35.718123  139.664468
# 14  15    Suginami   杉並区      570483    16750  34.06  35.699493  139.636288
# 15  16     Toshima   豊島区      294673    22650  13.01  35.736156  139.714222
# 16  17        Kita    北区      345063    16740  20.61  35.755838  139.736687
# 17  18     Arakawa   荒川区      213648    21030  10.16  35.737529  139.781310
# 18  19    Itabashi   板橋区      569225    17670  32.22  35.774143  139.681209
# 19  20      Nerima   練馬区      726748    15120  48.08  35.748360  139.638735
# 20  21      Adachi   足立区      674067    12660  53.25  35.783703  139.795319
# 21  22  Katsushika   葛飾区      447140    12850  34.80  35.751733  139.863816
# 22  23     Edogawa  江戸川区      685899    13750  49.90  35.678278  139.871091

# %% [markdown]
# ### 5.1) Clustering Neighborhoods in Tokyo

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     attrs-20.3.0               |     pyhd3deb0d_0          41 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36he6145b8_1001         347 KB  conda-forge
#     chardet-3.0.4              |py36h9880bd3_1008         194 KB  conda-forge
#     cryptography-3.2.1         |   py36h6ec43e4_0         633 KB  conda-forge
#     entrypoints-0.3            |  pyhd8ed1ab_1003           8 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.1.4               |   py36hd87012b_0        10.5 MB  conda-forge
#     pyrsistent-0.17.3          |   py36h1d69622_1          89 KB  conda-forge
#     pysocks-1.7.1              |   py36h9880bd3_2          27 KB  conda-forge
#     pytz-2020.4                |     pyhd8ed1ab_0         229 KB  conda-forge
#     requests-2.25.0            |     pyhd3deb0d_0          51 KB  conda-forge
#     toolz-0.11.1               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-20.3.0-pyhd3deb0d_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36he6145b8_1001
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9880bd3_1008
#   cryptography       conda-forge/linux-64::cryptography-3.2.1-py36h6ec43e4_0
#   entrypoints        conda-forge/noarch::entrypoints-0.3-pyhd8ed1ab_1003
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-2.0.0-1
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/noarch::jsonschema-3.2.0-py_2
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36he6145b8_2
#   pandas             conda-forge/linux-64::pandas-1.1.4-py36hd87012b_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.17.3-py36h1d69622_1
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9880bd3_2
#   pytz               conda-forge/noarch::pytz-2020.4-pyhd8ed1ab_0
#   requests           conda-forge/noarch::requests-2.25.0-pyhd3deb0d_0
#   toolz              conda-forge/noarch::toolz-0.11.1-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# entrypoints-0.3      | 8 KB      | ##################################### | 100%
# attrs-20.3.0         | 41 KB     | ##################################### | 100%
# pyrsistent-0.17.3    | 89 KB     | ##################################### | 100%
# pytz-2020.4          | 229 KB    | ##################################### | 100%
# cryptography-3.2.1   | 633 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# pandas-1.1.4         | 10.5 MB   | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 347 KB    | ##################################### | 100%
# chardet-3.0.4        | 194 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# requests-2.25.0      | 51 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# toolz-0.11.1         | 46 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ### 5.2) Get the geographical coordinates of Tokyo

# %%
address = 'Tokyo'

geolocator = Nominatim(user_agent="Tokyo_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Tokyo are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Tokyo are 35.6828387, 139.7594549.

# %% [markdown]
# ### 5.3) Visualization of the neighborhoods in Tokyo

# %%
# create map of Tokyo using latitude and longitude values
map_tokyo = folium.Map(location=[latitude, longitude], zoom_start=11)

 # add markers to map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tokyo) 
    
map_tokyo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 5.4) Setting up Foursquare Crededentials

# %% [markdown]
# ##### Define Foursquare Credentials and Version

# %%
# Credentials erased for privacy
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# CLIENT_SECRET:

# %%
df.loc[0, 'Name']
# Out:
# 'Chiyoda'

# %% [markdown]
# ### 5.5) Get the top 100 venues that are in Chiyoda within a radius of 500 meters

# %%
neighborhood_latitude = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'Name'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Chiyoda are 35.6938097, 139.7532163.

# %%
LIMIT = 100

radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=MQ0XIFC4T5X5MCUWN1M3VZ011RFZQPP5JZ1AO02PIIWJZPN0&client_secret=DO3SU02BKYOAAVWOWC33O2I5QZNZLI1ULXDJSWE4A0CHR5S5&v=20180604&ll=35.6938097,139.7532163&radius=500&limit=100'

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                           name          categories        lat         lng
# 0       Kanda Tendonya (神田天丼家)  Tempura Restaurant  35.695765  139.754682
# 1     Jimbocho Kurosu (神保町 黒須)    Ramen Restaurant  35.695539  139.754851
# 2       Nippon Budokan (日本武道館)             Stadium  35.693356  139.749865
# 3  Mori no Butchers (森のブッチャーズ)           Gastropub  35.694770  139.755980
# 4      Kitanomaru Park (北の丸公園)                Park  35.691653  139.751201

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 96 venues were returned by Foursquare.

# %%
print ('{} unique categories in Chiyoda'.format(nearby_venues['categories'].value_counts().shape[0]))
# Out:
# 49 unique categories in Chiyoda

# %%
print (nearby_venues['categories'].value_counts()[0:10])
# Out:
# Chinese Restaurant           7
# Café                         6
# Coffee Shop                  6
# Ramen Restaurant             6
# Convenience Store            6
# Historic Site                4
# Sake Bar                     4
# Indian Restaurant            3
# Japanese Curry Restaurant    3
# French Restaurant            3
# Name: categories, dtype: int64

# %% [markdown]
# ### 5.6) Exploring Neighborhoods in Tokyo

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']

    
    return(nearby_venues)

# %%
Tokyo_venues = getNearbyVenues(names=df['Name'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Chiyoda
# Chūō
# Minato
# Shinjuku
# Bunkyō
# Taitō
# Sumida
# Kōtō
# Shinagawa
# Meguro
# Ōta
# Setagaya
# Shibuya
# Nakano
# Suginami
# Toshima
# Kita
# Arakawa
# Itabashi
# Nerima
# Adachi
# Katsushika
# Edogawa

# %%
# Create a Data-Frame out of it to Concentrate Only on Restaurants 

Tokyo_Venues_only_restaurant = Tokyo_venues[Tokyo_venues['Venue Category'].str.contains('Restaurant')].reset_index(drop=True)
Tokyo_Venues_only_restaurant.index = np.arange(1, len(Tokyo_Venues_only_restaurant )+1)

# %%
print (Tokyo_Venues_only_restaurant['Venue Category'].value_counts())
# Out:
# Ramen Restaurant              58
# Japanese Restaurant           41
# Chinese Restaurant            41
# Sushi Restaurant              34
# Italian Restaurant            20
# Soba Restaurant               18
# Tonkatsu Restaurant           10
# Donburi Restaurant            10
# French Restaurant              7
# Yakitori Restaurant            7
# Indian Restaurant              7
# Yoshoku Restaurant             6
# Japanese Curry Restaurant      6
# Unagi Restaurant               6
# Seafood Restaurant             5
# Thai Restaurant                5
# Japanese Family Restaurant     5
# Dumpling Restaurant            5
# Teishoku Restaurant            4
# Restaurant                     3
# Kushikatsu Restaurant          3
# Nabe Restaurant                3
# Udon Restaurant                3
# Tempura Restaurant             3
# Shabu-Shabu Restaurant         2
# Szechuan Restaurant            2
# Brazilian Restaurant           2
# Korean Restaurant              2
# South Indian Restaurant        2
# Vietnamese Restaurant          2
# Sukiyaki Restaurant            2
# Kaiseki Restaurant             2
# Fast Food Restaurant           1
# Kebab Restaurant               1
# Kosher Restaurant              1
# Mexican Restaurant             1
# German Restaurant              1
# Hotpot Restaurant              1
# Dongbei Restaurant             1
# Asian Restaurant               1
# Middle Eastern Restaurant      1
# Russian Restaurant             1
# African Restaurant             1
# Monjayaki Restaurant           1
# Spanish Restaurant             1
# Taiwanese Restaurant           1
# Name: Venue Category, dtype: int64

# %%
print('There are {} uniques categories.'.format(len(Tokyo_Venues_only_restaurant['Venue Category'].unique())))
# Out:
# There are 46 uniques categories.

# %%
# create a dataframe of top 10 categories
Tokyo_5_Dist_Venues_Top10 = Tokyo_Venues_only_restaurant['Venue Category'].value_counts()[0:10].to_frame(name='frequency')
Tokyo_5_Dist_Venues_Top10=Tokyo_5_Dist_Venues_Top10.reset_index()
#Tokyo_5_Dist_Venues_Top10

Tokyo_5_Dist_Venues_Top10.rename(index=str, columns={"index": "Venue_Category", "frequency": "Frequency"}, inplace=True)
Tokyo_5_Dist_Venues_Top10
# Out:
#         Venue_Category  Frequency
# 0     Ramen Restaurant         58
# 1  Japanese Restaurant         41
# 2   Chinese Restaurant         41
# 3     Sushi Restaurant         34
# 4   Italian Restaurant         20
# 5      Soba Restaurant         18
# 6  Tonkatsu Restaurant         10
# 7   Donburi Restaurant         10
# 8    French Restaurant          7
# 9  Yakitori Restaurant          7

# %%
import seaborn as sns
from matplotlib import pyplot as plt

s=sns.barplot(x="Venue_Category", y="Frequency", data=Tokyo_5_Dist_Venues_Top10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('10 Most Frequently Occuring Venues in 23 Major Districts of Tokyo', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues1.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %% [markdown]
# #### Let's check the size of the resulting dataframe

# %%
print ("Shape of the Data-Frame with Venue Category only Restaurant: ", Tokyo_Venues_only_restaurant.shape)
Tokyo_Venues_only_restaurant.head(10)
# Out:
# Shape of the Data-Frame with Venue Category only Restaurant:  (340, 7)
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1       Chiyoda               35.69381              139.753216
# 2       Chiyoda               35.69381              139.753216
# 3       Chiyoda               35.69381              139.753216
# 4       Chiyoda               35.69381              139.753216
# 5       Chiyoda               35.69381              139.753216
# 6       Chiyoda               35.69381              139.753216
# 7       Chiyoda               35.69381              139.753216
# 8       Chiyoda               35.69381              139.753216
# 9       Chiyoda               35.69381              139.753216
# 10      Chiyoda               35.69381              139.753216
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 1         Kanda Tendonya (神田天丼家)       35.695765       139.754682
# 2       Jimbocho Kurosu (神保町 黒須)       35.695539       139.754851
# 3             Bondy (欧風カレー ボンディ)       35.695544       139.757356
# 4           Sushi Masa (九段下 寿司政)       35.695234       139.752227
# 5            Genrai Shuka (源来酒家)       35.695671       139.754409
# 6                           咸亨酒店       35.696010       139.756730
# 7                  Yojinbo (用心棒)       35.696409       139.756696
# 8            Fukumen Tomo (覆麺 智)       35.696403       139.757070
# 9   Mueang Thai Nabe (ムアン・タイ・なべ)       35.695344       139.757728
# 10                         たいよう軒       35.696454       139.754809
#
#                Venue Category
# 1          Tempura Restaurant
# 2            Ramen Restaurant
# 3   Japanese Curry Restaurant
# 4            Sushi Restaurant
# 5          Chinese Restaurant
# 6          Chinese Restaurant
# 7            Ramen Restaurant
# 8            Ramen Restaurant
# 9             Thai Restaurant
# 10         Chinese Restaurant

# %%
Tokyo_Venues_restaurant = Tokyo_Venues_only_restaurant.groupby(['Neighborhood'])['Venue Category'].apply(lambda x: x[x.str.contains('Restaurant')].count())

# %% [markdown]
# #### Analyze Each Neighborhood

# %%
Tokyo_Venues_restaurant
# Out:
# Neighborhood
# Adachi         3
# Arakawa        7
# Bunkyō         4
# Chiyoda       37
# Chūō          58
# Edogawa        4
# Itabashi       2
# Katsushika     5
# Kita          14
# Kōtō           3
# Meguro         6
# Minato        11
# Nakano         9
# Nerima         1
# Setagaya       7
# Shibuya       22
# Shinagawa      6
# Shinjuku      32
# Suginami      11
# Sumida         8
# Taitō         25
# Toshima       20
# Ōta           45
# Name: Venue Category, dtype: int64

# %%
Tokyo_Venues_restaurant_df  = Tokyo_Venues_restaurant.to_frame().reset_index()
Tokyo_Venues_restaurant_df.columns = ['Neighborhood', 'Number of Restaurant']
Tokyo_Venues_restaurant_df.index = np.arange(1, len(Tokyo_Venues_restaurant_df)+1)
list_rest_no =Tokyo_Venues_restaurant_df['Number of Restaurant'].to_list()
list_dist =Tokyo_Venues_restaurant_df['Neighborhood'].to_list()
print (list_rest_no)
print (list_dist)
# Out:
# [3, 7, 4, 37, 58, 4, 2, 5, 14, 3, 6, 11, 9, 1, 7, 22, 6, 32, 11, 8, 25, 20, 45]
# ['Adachi', 'Arakawa', 'Bunkyō', 'Chiyoda', 'Chūō', 'Edogawa', 'Itabashi', 'Katsushika', 'Kita', 'Kōtō', 'Meguro', 'Minato', 'Nakano', 'Nerima', 'Setagaya', 'Shibuya', 'Shinagawa', 'Shinjuku', 'Suginami', 'Sumida', 'Taitō', 'Toshima', 'Ōta']

# %%
# one hot encoding
Tokyo_onehot = pd.get_dummies(Tokyo_Venues_only_restaurant[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Tokyo_onehot['Neighborhood'] = Tokyo_Venues_only_restaurant['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Tokyo_onehot.columns[-1]] + Tokyo_5_Dist_Venues_restaurant_df + Tokyo_5_Dist_Venues_restaurant.to_frame().reset_index()
Tokyo_5_Dist_Venues_restaurant_df.columns = ['District', 'Number of Restaurant'](Tokyo_onehot.columns[:-1])
Tokyo_onehot = Tokyo_onehot[fixed_columns]

Tokyo_onehot.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-c60ae6f0c194> in <module>
#       6
#       7 # move neighborhood column to the first column
# ----> 8 fixed_columns = [Tokyo_onehot.columns[-1]] + Tokyo_5_Dist_Venues_restaurant_df + Tokyo_5_Dist_Venues_restaurant.to_frame().reset_index()
#       9 Tokyo_5_Dist_Venues_restaurant_df.columns = ['District', 'Number of Restaurant'](Tokyo_onehot.columns[:-1])
#      10 Tokyo_onehot = Tokyo_onehot[fixed_columns]
#
# NameError: name 'Tokyo_5_Dist_Venues_restaurant_df' is not defined

# %%
# And let's examine the new dataframe size.
Tokyo_onehot.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-575690723cc0> in <module>
#       1 # And let's examine the new dataframe size.
# ----> 2 Tokyo_onehot.shape
#
# NameError: name 'Tokyo_onehot' is not defined

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
Tokyo_grouped = Tokyo_onehot.groupby('Neighborhood').mean().reset_index()
Tokyo_grouped
# Out:
#    Neighborhood  Asian Restaurant  Brazilian Restaurant  Chinese Restaurant  \
# 0        Adachi          0.000000              0.000000            0.000000
# 1       Arakawa          0.000000              0.000000            0.125000
# 2        Bunkyō          0.000000              0.000000            0.333333
# 3       Chiyoda          0.000000              0.000000            0.216216
# 4          Chūō          0.000000              0.000000            0.015385
# 5       Edogawa          0.000000              0.000000            0.000000
# 6      Itabashi          0.000000              0.000000            0.500000
# 7    Katsushika          0.000000              0.000000            0.200000
# 8          Kita          0.000000              0.000000            0.083333
# 9          Kōtō          0.000000              0.000000            0.000000
# 10       Meguro          0.000000              0.000000            0.428571
# 11       Minato          0.000000              0.000000            0.181818
# 12       Nakano          0.000000              0.000000            0.100000
# 13       Nerima          0.000000              0.000000            1.000000
# 14     Setagaya          0.000000              0.000000            0.142857
# 15      Shibuya          0.047619              0.047619            0.142857
# 16    Shinagawa          0.000000              0.000000            0.000000
# 17     Shinjuku          0.000000              0.000000            0.033333
# 18     Suginami          0.090909              0.000000            0.090909
# 19       Sumida          0.000000              0.000000            0.000000
# 20        Taitō          0.000000              0.000000            0.045455
# 21      Toshima          0.000000              0.000000            0.090909
# 22          Ōta          0.000000              0.000000            0.119048
#
#     Donburi Restaurant  Dongbei Restaurant  Dumpling Restaurant  \
# 0             0.000000            0.000000             0.000000
# 1             0.125000            0.000000             0.000000
# 2             0.000000            0.000000             0.000000
# 3             0.000000            0.000000             0.000000
# 4             0.046154            0.000000             0.000000
# 5             0.000000            0.000000             0.000000
# 6             0.000000            0.000000             0.000000
# 7             0.200000            0.000000             0.100000
# 8             0.083333            0.000000             0.083333
# 9             0.000000            0.000000             0.000000
# 10            0.000000            0.000000             0.000000
# 11            0.000000            0.000000             0.000000
# 12            0.100000            0.000000             0.000000
# 13            0.000000            0.000000             0.000000
# 14            0.000000            0.000000             0.000000
# 15            0.047619            0.000000             0.000000
# 16            0.142857            0.000000             0.000000
# 17            0.000000            0.000000             0.000000
# 2                0.000000             0.000000            0.000000
# 3                0.000000             0.000000            0.027027
# 4                0.000000             0.015385            0.015385
# 5                0.000000             0.000000            0.000000
# 6                0.000000             0.000000            0.000000
# 7                0.000000             0.000000            0.000000
# 8                0.000000             0.000000            0.000000
# 9                0.000000             0.000000            0.000000
# 10               0.000000             0.000000            0.000000
# 11               0.000000             0.000000            0.000000
# 12               0.000000             0.000000            0.000000
# 13               0.000000             0.000000            0.000000
# 14               0.000000             0.000000            0.000000
# 15               0.000000             0.000000            0.000000
# 16               0.000000             0.000000            0.000000
# 17               0.000000             0.100000            0.033333
# 18               0.000000             0.000000            0.000000
# 19               0.000000             0.000000            0.000000
# 20               0.000000             0.000000            0.000000
# 21               0.000000             0.045455            0.045455
# 22               0.047619             0.000000            0.047619

# %% [markdown]
# #### Let's confirm the new size

# %%
Tokyo_grouped.shape
# Out:
# (23, 47)

# %% [markdown]
# #### Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in Tokyo_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Tokyo_grouped[Tokyo_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adachi----
#                  venue  freq
# 0           Restaurant   0.5
# 1  Japanese Restaurant   0.5
# 2     Asian Restaurant   0.0
# 3  Sukiyaki Restaurant   0.0
# 4   Russian Restaurant   0.0
#
#
# ----Arakawa----
#                 venue  freq
# 0    Ramen Restaurant  0.38
# 1   Indian Restaurant  0.25
# 2  Italian Restaurant  0.12
# 3  Chinese Restaurant  0.12
# 4  Donburi Restaurant  0.12
#
#
# ----Bunkyō----
#                  venue  freq
# 0   Italian Restaurant  0.33
# 1   Chinese Restaurant  0.33
# 2  Szechuan Restaurant  0.33
# 3     Sushi Restaurant  0.00
# 4           Restaurant  0.00
#
#
# ----Chiyoda----
#                        venue  freq
# 0         Chinese Restaurant  0.22
# 1           Ramen Restaurant  0.19
# 2  Japanese Curry Restaurant  0.08
# 3        Japanese Restaurant  0.08
# 4            Thai Restaurant  0.05
#
#
# ----Chūō----
#                  venue  freq
# 0     Sushi Restaurant  0.35
# 1  Japanese Restaurant  0.23
# 2      Soba Restaurant  0.06
# 3   Italian Restaurant  0.05
# 4   Donburi Restaurant  0.05
#
#
# ----Edogawa----
#                 venue  freq
# 0    Ramen Restaurant   0.5
# 1  Italian Restaurant   0.5
# 2          Restaurant   0.0
# 3  Russian Restaurant   0.0
# 4  Seafood Restaurant   0.0
#
#
# ----Itabashi----
#                 venue  freq
# 0  Chinese Restaurant   0.5
# 1          Restaurant   0.5
# 2    Asian Restaurant   0.0
# 3    Sushi Restaurant   0.0
# 4  Russian Restaurant   0.0
#
#
# ----Katsushika----
#                  venue  freq
# 0   Chinese Restaurant   0.2
# 1   Donburi Restaurant   0.2
# 2  Japanese Restaurant   0.2
# 3     Ramen Restaurant   0.1
# 4  Dumpling Restaurant   0.1
#
#
# ----Kita----
#                  venue  freq
# 0     Ramen Restaurant  0.33
# 1  Japanese Restaurant  0.25
# 2   Chinese Restaurant  0.08
# 3   Donburi Restaurant  0.08
# 4  Dumpling Restaurant  0.08
#
#
# ----Kōtō----
#                  venue  freq
# 0           Restaurant   1.0
# 1     Asian Restaurant   0.0
# 2  Sukiyaki Restaurant   0.0
# 3     Ramen Restaurant   0.0
# 4   Russian Restaurant   0.0
#
#
# ----Meguro----
#                  venue  freq
# 0   Chinese Restaurant  0.43
# 1  Japanese Restaurant  0.29
# 2   Italian Restaurant  0.14
# 3     Sushi Restaurant  0.14
# 4   Russian Restaurant  0.00
#
#
# ----Minato----
#                 venue  freq
# 0  Chinese Restaurant  0.18
# 1     Soba Restaurant  0.18
# 2    Kebab Restaurant  0.09
# 3   French Restaurant  0.09
# 4   Indian Restaurant  0.09
#
#
# ----Nakano----
#                     venue  freq
# 0        Ramen Restaurant   0.3
# 1      Chinese Restaurant   0.1
# 2      Donburi Restaurant   0.1
# 3  Okonomiyaki Restaurant   0.1
# 4     Tonkatsu Restaurant   0.1
#
#
# ----Nerima----
#                 venue  freq
# 0  Chinese Restaurant   1.0
# 1    Asian Restaurant   0.0
# 2    Sushi Restaurant   0.0
# 3          Restaurant   0.0
# 4  Russian Restaurant   0.0
#
#
# ----Setagaya----
#                   venue  freq
# 0      Ramen Restaurant  0.29
# 1   Japanese Restaurant  0.14
# 2    Chinese Restaurant  0.14
# 3  Fast Food Restaurant  0.14
# 4   Shanghai Restaurant  0.14
#
#
# ----Shibuya----
#                  venue  freq
# 0     Ramen Restaurant  0.19
# 1  Japanese Restaurant  0.19
# 2   Chinese Restaurant  0.14
# 3    French Restaurant  0.10
# 4     Asian Restaurant  0.05
#
#
# ----Shinagawa----
#                  venue  freq
# 0      Soba Restaurant  0.29
# 1   Italian Restaurant  0.14
# 2     Sushi Restaurant  0.14
# 3  Japanese Restaurant  0.14
# 4           Restaurant  0.14
#
#
# ----Shinjuku----
#                  venue  freq
# 0  Japanese Restaurant  0.20
# 1     Ramen Restaurant  0.17
# 2  Yakitori Restaurant  0.10
# 3  Tonkatsu Restaurant  0.07
# 4      Thai Restaurant  0.07
#
#
# ----Suginami----
#                     venue  freq
# 0        Ramen Restaurant  0.27
# 1      Italian Restaurant  0.18
# 2  Shabu-Shabu Restaurant  0.09
# 3         Soba Restaurant  0.09
# 4     Japanese Restaurant  0.09
#
#
# ----Sumida----
#                    venue  freq
# 0       Sushi Restaurant  0.25
# 1       Unagi Restaurant  0.25
# 2    Japanese Restaurant  0.25
# 3       Ramen Restaurant  0.25
# 4  Vietnamese Restaurant  0.00
#
#
# ----Taitō----
#                  venue  freq
# 0     Ramen Restaurant  0.18
# 1     Sushi Restaurant  0.14
# 2  Japanese Restaurant  0.14
# 3      Soba Restaurant  0.09
# 4  Sukiyaki Restaurant  0.09
#
#
# ----Toshima----
#                  venue  freq
# 0     Ramen Restaurant  0.23
# 1   Chinese Restaurant  0.09
# 2      Soba Restaurant  0.09
# 3  Japanese Restaurant  0.09
# 4  Tonkatsu Restaurant  0.09
#
#
# ----Ōta----
#                  venue  freq
# 0     Ramen Restaurant  0.26
# 1  Japanese Restaurant  0.17
# 2   Chinese Restaurant  0.12
# 3  Tonkatsu Restaurant  0.07
# 4     Sushi Restaurant  0.07

# %% [markdown]
# #### Let's put that into a *pandas* dataframe

# %%
# 22    Chinese Restaurant        Tonkatsu Restaurant       Sushi Restaurant
#
#      6th Most Common Venue      7th Most Common Venue  8th Most Common Venue  \
# 0        Kosher Restaurant          Korean Restaurant       Kebab Restaurant
# 1       Yoshoku Restaurant      Kushikatsu Restaurant      Kosher Restaurant
# 2    Kushikatsu Restaurant          Kosher Restaurant      Korean Restaurant
# 3               Restaurant         Italian Restaurant      Indian Restaurant
# 4         Unagi Restaurant         Tempura Restaurant       Ramen Restaurant
# 5        Kosher Restaurant          Korean Restaurant       Kebab Restaurant
# 6        Kosher Restaurant          Korean Restaurant       Kebab Restaurant
# 7         Ramen Restaurant          Korean Restaurant     Yoshoku Restaurant
# 8      Dumpling Restaurant         Italian Restaurant     Yoshoku Restaurant
# 9        Korean Restaurant           Kebab Restaurant     Kaiseki Restaurant
# 10       Indian Restaurant      Kushikatsu Restaurant      Kosher Restaurant
# 11      Kaiseki Restaurant          French Restaurant    Japanese Restaurant
# 12  Okonomiyaki Restaurant           Sushi Restaurant    Japanese Restaurant
# 13       Kosher Restaurant          Korean Restaurant       Kebab Restaurant
# 14         Soba Restaurant         Yoshoku Restaurant     Italian Restaurant
# 15    Brazilian Restaurant         Donburi Restaurant        Nabe Restaurant
# 16      Italian Restaurant         Yoshoku Restaurant      Indian Restaurant
# 17      Yoshoku Restaurant     Shabu-Shabu Restaurant  Kushikatsu Restaurant
# 18     Japanese Restaurant     Shabu-Shabu Restaurant        Soba Restaurant
# 19       Hotpot Restaurant          Kosher Restaurant      Korean Restaurant
# 20     Sukiyaki Restaurant       Monjayaki Restaurant        Nabe Restaurant
# 21      Yoshoku Restaurant  Middle Eastern Restaurant    Yakitori Restaurant
# 22      Yoshoku Restaurant      Vietnamese Restaurant   Taiwanese Restaurant
#
#         9th Most Common Venue     10th Most Common Venue
# 0          Kaiseki Restaurant  Japanese Curry Restaurant
# 1           Korean Restaurant           Kebab Restaurant
# 2            Kebab Restaurant         Kaiseki Restaurant
# 3             Soba Restaurant         Yoshoku Restaurant
# 4          Seafood Restaurant         Yoshoku Restaurant
# 5          Kaiseki Restaurant        Japanese Restaurant
# 6          Kaiseki Restaurant        Japanese Restaurant
# 7       Kushikatsu Restaurant          Kosher Restaurant
# 8       Kushikatsu Restaurant          Kosher Restaurant
# 9         Japanese Restaurant  Japanese Curry Restaurant
# 10          Korean Restaurant           Kebab Restaurant
# 11          Indian Restaurant         Yoshoku Restaurant
# 12         Yoshoku Restaurant          Kosher Restaurant
# 13         Kaiseki Restaurant        Japanese Restaurant
# 14          Kosher Restaurant          Korean Restaurant
# 15         Mexican Restaurant    South Indian Restaurant
# 16          Kosher Restaurant          Korean Restaurant
# 17  Japanese Curry Restaurant          Hotpot Restaurant
# 18          Kosher Restaurant          Korean Restaurant
# 19           Kebab Restaurant         Kaiseki Restaurant
# 20                 Restaurant           Halal Restaurant
# 21                 Restaurant         Seafood Restaurant
# 22        Dumpling Restaurant            Soba Restaurant

# %% [markdown]
# ## Cluster Neighborhoods

# %% [markdown]
# ### Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

Tokyo_grouped_clustering = Tokyo_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Tokyo_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 1, 4, 0, 0, 1, 2, 0, 0, 2], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels

neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

tokyo_merged = df

tokyo_merged.rename(columns={'Name':'Neighborhood'}, inplace=True)

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
tokyo_merged = tokyo_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

tokyo_merged.head() # check the last columns!
# Out:
#   No. Neighborhood Kanji  Population  Density   Area   Latitude   Longitude  \
# 0  01      Chiyoda  千代田区       59441     5100  11.66  35.693810  139.753216
# 1  02         Chūō   中央区      147620    14460  10.21  35.666255  139.775565
# 2  03       Minato    港区      248071    12180  20.37  35.643227  139.740055
# 3  04     Shinjuku   新宿区      339211    18620  18.22  35.693763  139.703632
# 4  05       Bunkyō   文京区      223389    19790  11.29  35.718810  139.744732
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0    Chinese Restaurant      Ramen Restaurant
# 1               0      Sushi Restaurant   Japanese Restaurant
# 2               0    Chinese Restaurant       Soba Restaurant
# 3               0   Japanese Restaurant      Ramen Restaurant
# 4               4    Chinese Restaurant   Szechuan Restaurant
#
#   3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 0   Japanese Restaurant  Japanese Curry Restaurant       Thai Restaurant
# 1       Soba Restaurant         Donburi Restaurant    Italian Restaurant
# 2     Kosher Restaurant          Korean Restaurant      Kebab Restaurant
# 3   Yakitori Restaurant        Tonkatsu Restaurant       Thai Restaurant
# 4    Italian Restaurant         Yoshoku Restaurant     Indian Restaurant
#
#    6th Most Common Venue   7th Most Common Venue  8th Most Common Venue  \
# 0             Restaurant      Italian Restaurant      Indian Restaurant
# 1       Unagi Restaurant      Tempura Restaurant       Ramen Restaurant
# 2     Kaiseki Restaurant       French Restaurant    Japanese Restaurant
# 3     Yoshoku Restaurant  Shabu-Shabu Restaurant  Kushikatsu Restaurant
# 4  Kushikatsu Restaurant       Kosher Restaurant      Korean Restaurant
#
#        9th Most Common Venue 10th Most Common Venue
# 0            Soba Restaurant     Yoshoku Restaurant
# 1         Seafood Restaurant     Yoshoku Restaurant
# 2          Indian Restaurant     Yoshoku Restaurant
# 3  Japanese Curry Restaurant      Hotpot Restaurant
# 4           Kebab Restaurant     Kaiseki Restaurant

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_restaurants10 = folium.Map(location=[latitude,longitude], tiles='cartodbpositron', 
                               attr="<a href=https://github.com/python-visualization/folium/>Folium</a>")

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
#rainbow = ['#00ff00', '#ff00ff','#0000ff','#ffa500' ,'#ff0000']
#Districts = ['Nagatacho', 'Nihonbashi', 'Shinjuku', 'Shinagawa', 'Shibuya']

# add markers to the map
for lat, lon, poi, cluster in zip(tokyo_merged['Latitude'], 
                                  tokyo_merged['Longitude'], 
                                  tokyo_merged['Neighborhood'], 
                                  tokyo_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=list_rest_no[list_dist.index(poi)]*0.5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_restaurants10)
       
map_restaurants10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine the Clusters

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# ## Cluster 1

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 0, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#    Neighborhood   Area   Latitude   Longitude  Cluster Labels  \
# 0       Chiyoda  11.66  35.693810  139.753216               0
# 1          Chūō  10.21  35.666255  139.775565               0
# 2        Minato  20.37  35.643227  139.740055               0
# 3      Shinjuku  18.22  35.693763  139.703632               0
# 5         Taitō  10.11  35.717450  139.790859               0
# 6        Sumida  13.77  35.700429  139.805017               0
# 8     Shinagawa  22.84  35.599252  139.738910               0
# 9        Meguro  14.67  35.621250  139.688014               0
# 10          Ōta  60.66  35.561206  139.715843               0
# 11     Setagaya  58.05  35.646530  139.653250               0
# 12      Shibuya  15.11  35.664596  139.698711               0
# 13       Nakano  15.59  35.718123  139.664468               0
# 14     Suginami  34.06  35.699493  139.636288               0
# 15      Toshima  13.01  35.736156  139.714222               0
# 16         Kita  20.61  35.755838  139.736687               0
# 21   Katsushika  34.80  35.751733  139.863816               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0
# 16         Italian Restaurant     Yoshoku Restaurant
# 21          Korean Restaurant     Yoshoku Restaurant
#
#         9th Most Common Venue   10th Most Common Venue
# 0             Soba Restaurant       Yoshoku Restaurant
# 1          Seafood Restaurant       Yoshoku Restaurant
# 2           Indian Restaurant       Yoshoku Restaurant
# 3   Japanese Curry Restaurant        Hotpot Restaurant
# 5                  Restaurant         Halal Restaurant
# 6            Kebab Restaurant       Kaiseki Restaurant
# 8           Kosher Restaurant        Korean Restaurant
# 9           Korean Restaurant         Kebab Restaurant
# 10        Dumpling Restaurant          Soba Restaurant
# 11          Kosher Restaurant        Korean Restaurant
# 12         Mexican Restaurant  South Indian Restaurant
# 13         Yoshoku Restaurant        Kosher Restaurant
# 14          Kosher Restaurant        Korean Restaurant
# 15                 Restaurant       Seafood Restaurant
# 16      Kushikatsu Restaurant        Kosher Restaurant
# 21      Kushikatsu Restaurant        Kosher Restaurant

# %% [markdown]
# ## Cluster 2

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 1, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#    Neighborhood   Area   Latitude   Longitude  Cluster Labels  \
# 17      Arakawa  10.16  35.737529  139.781310               1
# 22      Edogawa  49.90  35.678278  139.871091               1
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 17      Ramen Restaurant     Indian Restaurant    Italian Restaurant
# 22      Ramen Restaurant    Italian Restaurant    Yoshoku Restaurant
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 17    Chinese Restaurant     Donburi Restaurant    Yoshoku Restaurant
# 22     Indian Restaurant  Kushikatsu Restaurant     Kosher Restaurant
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 17  Kushikatsu Restaurant     Kosher Restaurant     Korean Restaurant
# 22      Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
#
#    10th Most Common Venue
# 17       Kebab Restaurant
# 22    Japanese Restaurant

# %% [markdown]
# ## Cluster 3

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 2, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#    Neighborhood   Area   Latitude   Longitude  Cluster Labels  \
# 7          Kōtō  40.16  35.649154  139.812790               2
# 18     Itabashi  32.22  35.774143  139.681209               2
# 20       Adachi  53.25  35.783703  139.795319               2
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 7             Restaurant    Yoshoku Restaurant     Indian Restaurant
# 18    Chinese Restaurant            Restaurant    Yoshoku Restaurant
# 20            Restaurant   Japanese Restaurant    Yoshoku Restaurant
#
#     4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 7   Kushikatsu Restaurant      Kosher Restaurant     Korean Restaurant
# 18      Indian Restaurant  Kushikatsu Restaurant     Kosher Restaurant
# 20      Indian Restaurant  Kushikatsu Restaurant     Kosher Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 7       Kebab Restaurant    Kaiseki Restaurant   Japanese Restaurant
# 18     Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
# 20     Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
#
#        10th Most Common Venue
# 7   Japanese Curry Restaurant
# 18        Japanese Restaurant
# 20  Japanese Curry Restaurant

# %% [markdown]
# ## Cluster 4

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 3, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#    Neighborhood   Area  Latitude   Longitude  Cluster Labels  \
# 19       Nerima  48.08  35.74836  139.638735               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 19    Chinese Restaurant    Yoshoku Restaurant     Indian Restaurant
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 19    Mexican Restaurant  Kushikatsu Restaurant     Kosher Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 19     Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
#
#    10th Most Common Venue
# 19    Japanese Restaurant

# %% [markdown]
# ## Cluster 5

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 4, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#   Neighborhood   Area  Latitude   Longitude  Cluster Labels  \
# 4       Bunkyō  11.29  35.71881  139.744732               4
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 4    Chinese Restaurant   Szechuan Restaurant    Italian Restaurant
#
#   4th Most Common Venue 5th Most Common Venue  6th Most Common Venue  \
# 4    Yoshoku Restaurant     Indian Restaurant  Kushikatsu Restaurant
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 4     Kosher Restaurant     Korean Restaurant      Kebab Restaurant
#
#   10th Most Common Venue
# 4     Kaiseki Restaurant
